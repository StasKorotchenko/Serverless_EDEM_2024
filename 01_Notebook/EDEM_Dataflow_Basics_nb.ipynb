# %% [markdown]
# #### Script: Dataflow Basics
#
# Description: Notebook where we will see the functioning of each transformation discussed during the theory.
#
# EDEM. Master Data Analytics<br>
# Professor: Javi Briones

# %% [markdown]
# ### Setup

# %%
# GCP Auth

# Local
# !gcloud auth application-default login

# Google Colab
# from google.colab import auth
# auth.authenticate_user()

# %%
# Install requirements
# !pip install "apache_beam[interactive]"
# Out:
# Collecting apache_beam[interactive]
#   Downloading apache-beam-2.53.0.tar.gz (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 8.0 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting crcmod<2.0,>=1.7 (from apache_beam[interactive])
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 4.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting orjson<4,>=3.9.7 (from apache_beam[interactive])
#   Downloading orjson-3.9.12-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 3.8 MB/s eta 0:00:00
# Collecting dill<0.3.2,>=0.3.1.1 (from apache_beam[interactive])
#   Downloading dill-0.3.1.1.tar.gz (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 9.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting cloudpickle~=2.2.1 (from apache_beam[interactive])
#   Downloading cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting fastavro<2,>=0.23.6 (from apache_beam[interactive])
#   Downloading fastavro-1.9.3-cp311-cp311-macosx_10_9_universal2.whl.metadata (5.5 kB)
# Collecting fasteners<1.0,>=0.3 (from apache_beam[interactive])
#   Downloading fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
# Collecting grpcio!=1.48.0,<2,>=1.33.1 (from apache_beam[interactive])
#   Using cached grpcio-1.60.0-cp311-cp311-macosx_10_10_universal2.whl.metadata (4.0 kB)
# Collecting hdfs<3.0.0,>=2.1.0 (from apache_beam[interactive])
#   Downloading hdfs-2.7.3.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 6.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting httplib2<0.23.0,>=0.8 (from apache_beam[interactive])
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 5.0 MB/s eta 0:00:00
# Collecting js2py<1,>=0.74 (from apache_beam[interactive])
#   Downloading Js2Py-0.74-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 16.0 MB/s eta 0:00:00a 0:00:01
# Collecting jsonschema<5.0.0,>=4.0.0 (from apache_beam[interactive])
#   Downloading jsonschema-4.21.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting jsonpickle<4.0.0,>=3.0.0 (from apache_beam[interactive])
#   Downloading jsonpickle-3.0.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting numpy<1.25.0,>=1.14.3 (from apache_beam[interactive])
#   Using cached numpy-1.24.4-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.6 kB)
# Collecting objsize<0.7.0,>=0.6.1 (from apache_beam[interactive])
#   Downloading objsize-0.6.1-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: packaging>=22.0 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from apache_beam[interactive]) (23.1)
# Collecting pymongo<5.0.0,>=3.8.0 (from apache_beam[interactive])
#   Downloading pymongo-4.6.1-cp311-cp311-macosx_10_9_universal2.whl.metadata (22 kB)
# Collecting proto-plus<2,>=1.7.1 (from apache_beam[interactive])
#   Downloading proto_plus-1.23.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<4.26.0,>=3.20.3 (from apache_beam[interactive])
#   Using cached protobuf-4.25.2-cp37-abi3-macosx_10_9_universal2.whl.metadata (541 bytes)
# Collecting pydot<2,>=1.2.0 (from apache_beam[interactive])
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from apache_beam[interactive]) (2.8.2)
# Requirement already satisfied: pytz>=2018.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[interactive]) (2023.3.post1)
# Collecting regex>=2020.6.8 (from apache_beam[interactive])
#   Downloading regex-2023.12.25-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[interactive]) (2.31.0)
# Collecting typing-extensions>=3.7.0 (from apache_beam[interactive])
#   Downloading typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting zstandard<1,>=0.18.0 (from apache_beam[interactive])
#   Downloading zstandard-0.22.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.9 kB)
# Collecting pyarrow<15.0.0,>=3.0.0 (from apache_beam[interactive])
#   Downloading pyarrow-14.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting pyarrow-hotfix<1 (from apache_beam[interactive])
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl.metadata (3.6 kB)
# Collecting facets-overview<2,>=1.1.0 (from apache_beam[interactive])
#   Downloading facets_overview-1.1.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting google-cloud-dataproc<6,>=5.0.0 (from apache_beam[interactive])
#   Downloading google_cloud_dataproc-5.8.0-py2.py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: ipython<9,>=8 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from apache_beam[interactive]) (8.16.0)
# Requirement already satisfied: ipykernel<7,>=6 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from apache_beam[interactive]) (6.25.2)
# Collecting ipywidgets<9,>=8 (from apache_beam[interactive])
#   Downloading ipywidgets-8.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting jupyter-client!=6.1.13,<8.2.1,>=6.1.11 (from apache_beam[interactive])
#   Downloading jupyter_client-8.2.0-py3-none-any.whl (103 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 5.3 MB/s eta 0:00:00
# Collecting timeloop<2,>=1.0.2 (from apache_beam[interactive])
#   Downloading timeloop-1.0.2.tar.gz (2.9 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting nbformat<6,>=5.0.5 (from apache_beam[interactive])
#   Downloading nbformat-5.9.2-py3-none-any.whl.metadata (3.4 kB)
# Collecting nbconvert<8,>=6.2.0 (from apache_beam[interactive])
#   Downloading nbconvert-7.14.2-py3-none-any.whl.metadata (7.7 kB)
# Collecting pandas!=1.5.0,!=1.5.1,<1.6,>=1.4.3 (from apache_beam[interactive])
#   Downloading pandas-1.5.3-cp311-cp311-macosx_11_0_arm64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 16.3 MB/s eta 0:00:0000:0100:01
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive])
#   Downloading google_api_core-2.15.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting grpc-google-iam-v1<1.0.0dev,>=0.12.4 (from google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive])
#   Downloading grpc_google_iam_v1-0.13.0-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting docopt (from hdfs<3.0.0,>=2.1.0->apache_beam[interactive])
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: six>=1.9.0 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from hdfs<3.0.0,>=2.1.0->apache_beam[interactive]) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httplib2<0.23.0,>=0.8->apache_beam[interactive]) (3.1.1)
# Requirement already satisfied: appnope in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (1.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (5.3.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (0.1.6)
# Requirement already satisfied: nest-asyncio in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (1.5.8)
# Requirement already satisfied: psutil in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (25.1.1)
# Requirement already satisfied: tornado>=6.1 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (6.3.3)
# Requirement already satisfied: traitlets>=5.4.0 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipykernel<7,>=6->apache_beam[interactive]) (5.10.1)
# Requirement already satisfied: backcall in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipython<9,>=8->apache_beam[interactive]) (0.2.0)
# Requirement already satisfied: decorator in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipython<9,>=8->apache_beam[interactive]) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipython<9,>=8->apache_beam[interactive]) (0.19.0)
# Requirement already satisfied: pickleshare in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipython<9,>=8->apache_beam[interactive]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipython<9,>=8->apache_beam[interactive]) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipython<9,>=8->apache_beam[interactive]) (2.16.1)
# Requirement already satisfied: stack-data in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipython<9,>=8->apache_beam[interactive]) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from ipython<9,>=8->apache_beam[interactive]) (4.8.0)
# Collecting widgetsnbextension~=4.0.9 (from ipywidgets<9,>=8->apache_beam[interactive])
#   Downloading widgetsnbextension-4.0.9-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.9 (from ipywidgets<9,>=8->apache_beam[interactive])
#   Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl.metadata (4.1 kB)
# Collecting tzlocal>=1.2 (from js2py<1,>=0.74->apache_beam[interactive])
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting pyjsparser>=2.5.1 (from js2py<1,>=0.74->apache_beam[interactive])
#   Downloading pyjsparser-2.7.1.tar.gz (24 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting attrs>=22.2.0 (from jsonschema<5.0.0,>=4.0.0->apache_beam[interactive])
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema<5.0.0,>=4.0.0->apache_beam[interactive])
#   Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema<5.0.0,>=4.0.0->apache_beam[interactive])
#   Downloading referencing-0.32.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema<5.0.0,>=4.0.0->apache_beam[interactive])
#   Downloading rpds_py-0.17.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting beautifulsoup4 (from nbconvert<8,>=6.2.0->apache_beam[interactive])
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting bleach!=5.0.0 (from nbconvert<8,>=6.2.0->apache_beam[interactive])
#   Downloading bleach-6.1.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert<8,>=6.2.0->apache_beam[interactive])
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: jinja2>=3.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert<8,>=6.2.0->apache_beam[interactive]) (3.1.2)
# Collecting jupyterlab-pygments (from nbconvert<8,>=6.2.0->apache_beam[interactive])
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: markupsafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from nbconvert<8,>=6.2.0->apache_beam[interactive]) (2.1.3)
# Collecting mistune<4,>=2.0.3 (from nbconvert<8,>=6.2.0->apache_beam[interactive])
#   Downloading mistune-3.0.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert<8,>=6.2.0->apache_beam[interactive])
#   Downloading nbclient-0.9.0-py3-none-any.whl.metadata (7.8 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert<8,>=6.2.0->apache_beam[interactive])
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting tinycss2 (from nbconvert<8,>=6.2.0->apache_beam[interactive])
#   Downloading tinycss2-1.2.1-py3-none-any.whl (21 kB)
# Collecting fastjsonschema (from nbformat<6,>=5.0.5->apache_beam[interactive])
#   Downloading fastjsonschema-2.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo<5.0.0,>=3.8.0->apache_beam[interactive])
#   Downloading dnspython-2.4.2-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.24.0->apache_beam[interactive]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.24.0->apache_beam[interactive]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.24.0->apache_beam[interactive]) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.24.0->apache_beam[interactive]) (2023.11.17)
# Collecting webencodings (from bleach!=5.0.0->nbconvert<8,>=6.2.0->apache_beam[interactive])
#   Downloading webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive])
#   Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting google-auth<3.0.dev0,>=2.14.1 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive])
#   Downloading google_auth-2.26.2-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive])
#   Downloading grpcio_status-1.60.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from jedi>=0.16->ipython<9,>=8->apache_beam[interactive]) (0.8.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel<7,>=6->apache_beam[interactive]) (3.10.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from pexpect>4.3->ipython<9,>=8->apache_beam[interactive]) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9,>=8->apache_beam[interactive]) (0.2.7)
# Collecting soupsieve>1.2 (from beautifulsoup4->nbconvert<8,>=6.2.0->apache_beam[interactive])
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: executing>=1.2.0 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython<9,>=8->apache_beam[interactive]) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython<9,>=8->apache_beam[interactive]) (2.4.0)
# Requirement already satisfied: pure-eval in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from stack-data->ipython<9,>=8->apache_beam[interactive]) (0.2.2)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive])
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive])
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.3/181.3 kB 9.2 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive])
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1<0.6.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-dataproc<6,>=5.0.0->apache_beam[interactive])
#   Downloading pyasn1-0.5.1-py2.py3-none-any.whl.metadata (8.6 kB)
# Downloading facets_overview-1.1.1-py2.py3-none-any.whl (22 kB)
# Downloading fastavro-1.9.3-cp311-cp311-macosx_10_9_universal2.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 17.1 MB/s eta 0:00:00a 0:00:01
# Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Downloading google_cloud_dataproc-5.8.0-py2.py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.8/307.8 kB 18.5 MB/s eta 0:00:00
# Using cached grpcio-1.60.0-cp311-cp311-macosx_10_10_universal2.whl (9.7 MB)
# Downloading ipywidgets-8.1.1-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.4/139.4 kB 11.2 MB/s eta 0:00:00
# Downloading jsonpickle-3.0.2-py3-none-any.whl (40 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.7/40.7 kB 5.0 MB/s eta 0:00:00
# Downloading jsonschema-4.21.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.1/85.1 kB 11.9 MB/s eta 0:00:00
# Downloading nbconvert-7.14.2-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.4/256.4 kB 15.6 MB/s eta 0:00:00
# Downloading nbformat-5.9.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.6/77.6 kB 8.9 MB/s eta 0:00:00
# Using cached numpy-1.24.4-cp311-cp311-macosx_11_0_arm64.whl (13.8 MB)
# Downloading orjson-3.9.12-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.6/250.6 kB 13.1 MB/s eta 0:00:00
# Downloading proto_plus-1.23.0-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 7.8 MB/s eta 0:00:00
# Using cached protobuf-4.25.2-cp37-abi3-macosx_10_9_universal2.whl (394 kB)
# Downloading pyarrow-14.0.2-cp311-cp311-macosx_11_0_arm64.whl (24.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 17.1 MB/s eta 0:00:0000:0100:01
# Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Downloading pymongo-4.6.1-cp311-cp311-macosx_10_9_universal2.whl (534 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 534.3/534.3 kB 4.7 MB/s eta 0:00:00a 0:00:01m
# Downloading regex-2023.12.25-cp311-cp311-macosx_11_0_arm64.whl (291 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 291.0/291.0 kB 19.8 MB/s eta 0:00:00
# Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Downloading zstandard-0.22.0-cp311-cp311-macosx_11_0_arm64.whl (703 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 703.4/703.4 kB 16.7 MB/s eta 0:00:0000:01
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 6.6 MB/s eta 0:00:00
# Downloading bleach-6.1.0-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.8/162.8 kB 19.4 MB/s eta 0:00:00
# Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 18.0 MB/s eta 0:00:00
# Downloading google_api_core-2.15.0-py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.0/122.0 kB 11.5 MB/s eta 0:00:00
# Downloading grpc_google_iam_v1-0.13.0-py2.py3-none-any.whl (25 kB)
# Downloading jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading jupyterlab_widgets-3.0.9-py3-none-any.whl (214 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.9/214.9 kB 16.4 MB/s eta 0:00:00
# Downloading mistune-3.0.2-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 5.0 MB/s eta 0:00:00
# Downloading nbclient-0.9.0-py3-none-any.whl (24 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading referencing-0.32.1-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.17.1-cp311-cp311-macosx_11_0_arm64.whl (352 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 352.9/352.9 kB 19.4 MB/s eta 0:00:00
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Downloading widgetsnbextension-4.0.9-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 18.0 MB/s eta 0:00:00a 0:00:01
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.9/147.9 kB 13.6 MB/s eta 0:00:00
# Downloading fastjsonschema-2.19.1-py3-none-any.whl (23 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading google_auth-2.26.2-py2.py3-none-any.whl (186 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.5/186.5 kB 24.9 MB/s eta 0:00:00
# Downloading googleapis_common_protos-1.62.0-py2.py3-none-any.whl (228 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.7/228.7 kB 15.9 MB/s eta 0:00:00
# Downloading grpcio_status-1.60.0-py3-none-any.whl (14 kB)
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading pyasn1-0.5.1-py2.py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.9/84.9 kB 9.8 MB/s eta 0:00:00
# Building wheels for collected packages: crcmod, dill, hdfs, timeloop, apache_beam, pyjsparser, docopt
#   Building wheel for crcmod (pyproject.toml) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp311-cp311-macosx_10_9_universal2.whl size=25808 sha256=0d621a63ee8c3ec3a9ec1275efd7df30afbfe4913f50489072e3c09d95d82815
#   Stored in directory: /Users/korotchenkostanislav/Library/Caches/pip/wheels/23/94/7a/8cb7d14597e6395ce969933f01aed9ea8fa5f5b4d4c8a61e99
#   Building wheel for dill (pyproject.toml) ... done
#   Created wheel for dill: filename=dill-0.3.1.1-py3-none-any.whl size=78540 sha256=01228247a83ae3feb48502bc49ad59db8464a21051329fe22c6744b301cd452a
#   Stored in directory: /Users/korotchenkostanislav/Library/Caches/pip/wheels/01/60/80/1622338bcecce31a5664ef01c203cc5a7b09f59588d9c07376
#   Building wheel for hdfs (pyproject.toml) ... done
#   Created wheel for hdfs: filename=hdfs-2.7.3-py3-none-any.whl size=34325 sha256=a07400e38e2838b4bc564ac9157fb12ce0291800612e1a878d327af16167d5c5
#   Stored in directory: /Users/korotchenkostanislav/Library/Caches/pip/wheels/b9/1d/dc/eb0833be25464c359903d356c4204721c6a672c26ff164cdc3
#   Building wheel for timeloop (pyproject.toml) ... done
#   Created wheel for timeloop: filename=timeloop-1.0.2-py3-none-any.whl size=3702 sha256=d069b2ea46699c13ebcd4af17defee33fcdf68508e830ecf7f891f4392cb8314
#   Stored in directory: /Users/korotchenkostanislav/Library/Caches/pip/wheels/2d/3a/1e/06ec29bdc5c9068e538e66a6a82de19f4579fd9b1a6614084d
#   Building wheel for apache_beam (pyproject.toml) ... done
#   Created wheel for apache_beam: filename=apache_beam-2.53.0-cp311-cp311-macosx_10_9_universal2.whl size=7214538 sha256=eea601ed80dfb924c6e37ad3223ebf3eb45266f79e207ca7684d3358b3ffbffa
#   Stored in directory: /Users/korotchenkostanislav/Library/Caches/pip/wheels/dd/ff/1d/19c9650e0abbf669c3a473ccd400b3ed4bb11c16ec7df19fb8
#   Building wheel for pyjsparser (pyproject.toml) ... done
#   Created wheel for pyjsparser: filename=pyjsparser-2.7.1-py3-none-any.whl size=25984 sha256=785092a6133a733787d505de319cbc9cd57078ba8907b57edcdcd45928386240
#   Stored in directory: /Users/korotchenkostanislav/Library/Caches/pip/wheels/a5/9a/30/1003e89ab4555b81840ca46d361bf184f1e6ad880cae3b62a9
#   Building wheel for docopt (pyproject.toml) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13706 sha256=ec882f46521bba6983ab4b2aef1c535bb1ab59376654c6d8bc08612ce485fd1d
#   Stored in directory: /Users/korotchenkostanislav/Library/Caches/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
# Successfully built crcmod dill hdfs timeloop apache_beam pyjsparser docopt
# Installing collected packages: webencodings, timeloop, pyjsparser, fastjsonschema, docopt, crcmod, zstandard, widgetsnbextension, tzlocal, typing-extensions, tinycss2, soupsieve, rpds-py, regex, pydot, pyasn1, pyarrow-hotfix, protobuf, pandocfilters, orjson, objsize, numpy, mistune, jupyterlab-widgets, jupyterlab-pygments, jsonpickle, httplib2, grpcio, fasteners, fastavro, dnspython, dill, defusedxml, cloudpickle, cachetools, bleach, attrs, rsa, referencing, pymongo, pyasn1-modules, pyarrow, proto-plus, pandas, jupyter-client, js2py, hdfs, googleapis-common-protos, beautifulsoup4, jsonschema-specifications, grpcio-status, google-auth, facets-overview, jsonschema, ipywidgets, grpc-google-iam-v1, google-api-core, nbformat, apache_beam, nbclient, google-cloud-dataproc, nbconvert
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.1
#     Uninstalling numpy-1.26.1:
#       Successfully uninstalled numpy-1.26.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.2
#     Uninstalling pandas-2.1.2:
#       Successfully uninstalled pandas-2.1.2
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter_client 8.3.1
#     Uninstalling jupyter_client-8.3.1:
#       Successfully uninstalled jupyter_client-8.3.1
# Successfully installed apache_beam-2.53.0 attrs-23.2.0 beautifulsoup4-4.12.3 bleach-6.1.0 cachetools-5.3.2 cloudpickle-2.2.1 crcmod-1.7 defusedxml-0.7.1 dill-0.3.1.1 dnspython-2.4.2 docopt-0.6.2 facets-overview-1.1.1 fastavro-1.9.3 fasteners-0.19 fastjsonschema-2.19.1 google-api-core-2.15.0 google-auth-2.26.2 google-cloud-dataproc-5.8.0 googleapis-common-protos-1.62.0 grpc-google-iam-v1-0.13.0 grpcio-1.60.0 grpcio-status-1.60.0 hdfs-2.7.3 httplib2-0.22.0 ipywidgets-8.1.1 js2py-0.74 jsonpickle-3.0.2 jsonschema-4.21.0 jsonschema-specifications-2023.12.1 jupyter-client-8.2.0 jupyterlab-pygments-0.3.0 jupyterlab-widgets-3.0.9 mistune-3.0.2 nbclient-0.9.0 nbconvert-7.14.2 nbformat-5.9.2 numpy-1.24.4 objsize-0.6.1 orjson-3.9.12 pandas-1.5.3 pandocfilters-1.5.1 proto-plus-1.23.0 protobuf-4.25.2 pyarrow-14.0.2 pyarrow-hotfix-0.6 pyasn1-0.5.1 pyasn1-modules-0.3.0 pydot-1.4.2 pyjsparser-2.7.1 pymongo-4.6.1 referencing-0.32.1 regex-2023.12.25 rpds-py-0.17.1 rsa-4.9 soupsieve-2.5 timeloop-1.0.2 tinycss2-1.2.1 typing-extensions-4.9.0 tzlocal-5.2 webencodings-0.5.1 widgetsnbextension-4.0.9 zstandard-0.22.0
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
# Import Python Libraries
import logging
import apache_beam as beam
from apache_beam.runners.interactive.interactive_runner import InteractiveRunner
import apache_beam.runners.interactive.interactive_beam as ib

# %% [markdown]
# ### Beam Basics

# %% [markdown]
# <img src="../00_DocAux/.images/Beam_Pipeline.png" width="1000"/>

# %% [markdown]
# ##### 01 Understanding basic concepts: PCollection, PTransform & Pipeline Object

# %%
with beam.Pipeline(InteractiveRunner()) as p:

    (p   
        | "Read Text from a File" >> beam.io.ReadFromText('../00_DocAux/input_text.txt')
        | "Split" >> beam.FlatMap(lambda line: line.split(' '))
        | 
        | "countwords" >> beam.combiners.Count.PerElement()
        | "Show content" >> beam.Map(print))
# Out:
# ('En', 1)
# ('un', 2)
# ('lugar', 1)
# ('de', 12)
# ('la', 1)
# ('Mancha,', 1)
# ('cuyo', 1)
# ('nombre', 1)
# ('no', 2)
# ('quiero', 1)
# ('acordarme,', 1)
# ('ha', 1)
# ('mucho', 1)
# ('tiempo', 1)
# ('que', 2)
# ('vivía', 1)
# ('hidalgo', 1)
# ('los', 5)
# ('lanza', 1)
# ('en', 1)
# ('astillero,', 1)
# ('adarga', 1)
# ('antigua,', 1)
# ('rocín', 1)
# ('flaco', 1)
# ('y', 2)
# ('galgo', 1)
# ('corredor.', 1)
# ('Una', 1)
# ('olla', 1)
# ('algo', 1)
# ('más', 3)
# ('vaca', 1)
# ('carnero,', 1)
# ('salpicón', 1)
# ('las', 3)
# ('noches,', 1)
# ('duelos', 1)
# ('quebrantos', 1)
# ('sábados,', 1)
# ('lantejas', 1)
# ('viernes,', 1)
# ('algún', 1)
# ('palomino', 1)
# ('añadidura', 1)
# ('domingos,', 1)
# ('consumían', 1)
# ('tres', 1)
# ('partes', 1)
# ('su', 2)
# ('hacienda.', 1)
# ('El', 1)
# ('resto', 1)
# ('della', 1)
# ('concluían', 1)
# ('sayo', 1)
# ('velarte,', 1)
# ('calzas', 1)
# ('velludo', 1)
# ('para', 1)
# ('fiestas', 1)
# ('con', 2)
# ('sus', 1)
# ('pantuflos', 1)
# ('lo', 2)
# ('mismo,', 1)
# ('días', 1)
# ('entre', 1)
# ('semana', 1)
# ('se', 1)
# ('honraba', 1)
# ('vellorí', 1)
# ('fino.', 1)

# %% [markdown]
# ##### 02 Understanding Core Transformations: DoFn & Map

# %%
# Map
def edem_map(element, num):
    return element * num

# DoFn
class edemDoFn(beam.DoFn):

    def __init__(self, num):
        self.num_ = num

    def process(self, element):
        yield element * self.num_

# Pipeline
with beam.Pipeline(InteractiveRunner()) as p:
  data = (
      p 
        | "Create a PCollection" >> beam.Create([1,2,3,4,5])
        | "Map" >> beam.Map(edem_map, num=2)
        | "DoFn" >> beam.ParDo(edemDoFn(4))
        | "Print" >> beam.Map(print)
  )

# %%
# PTransform
class edem_PTransform(beam.PTransform):

    # Map
    def edem_map(element):
        return element * 2

    # DoFn
    class edemDoFn(beam.DoFn):

        def process(self, element, num):
            yield element * num
    
    def expand(self,PColl):
        
        PColl_ = (PColl 
            | "Map" >> beam.Map(lambda x: x * 2)
            | "ParDo" >> beam.ParDo(edemDoFn(), num=4)
            | "Print" >> beam.Map(print))
        
        yield PColl_

# Pipeline
with beam.Pipeline(InteractiveRunner()) as p:
    data = (
        p 
            | "Create a PCollection" >> beam.Create([1,2,3,4,5])
    )
    
    data | edem_PTransform() | "Print" >> beam.Map(print)

# %% [markdown]
# ##### 03 DoFn Lifecycle

# %%
from datetime import datetime
class DoFnLifeCycle(beam.DoFn):

  def now(self):
    self._now = datetime.now()
    return self._now

  def __init__(self):
    print("Constructor started at: %s" % self.now())

  def setup(self):
    print("worker started at: %s" % self.now())

  def start_bundle(self):
    print("bundle started at: %s" % self.now())

  def process(self, element):
    words = element.split()
    for word in words:
      print("Processing element: %s" % word)
      yield word.upper()

  def finish_bundle(self):
    print("bundle finished at: %s" % self.now())

  def teardown(self):
    print("worker finished at: %s" % self.now())

with beam.Pipeline(InteractiveRunner()) as p:
  input_data = (
      p 
        | "Reading the input file" >> beam.io.ReadFromText('../00_DocAux/input_text.txt')
        | "DoFn Life Cycle" >> beam.ParDo(DoFnLifeCycle())
  )
# Out:
# Constructor started at: 2024-01-19 20:21:12.247416
# worker started at: 2024-01-19 20:21:12.611946
# bundle started at: 2024-01-19 20:21:12.613283
# Processing element: En
# Processing element: un
# Processing element: lugar
# Processing element: de
# Processing element: la
# Processing element: Mancha,
# Processing element: de
# Processing element: cuyo
# Processing element: nombre
# Processing element: no
# Processing element: quiero
# Processing element: acordarme,
# Processing element: no
# Processing element: ha
# Processing element: mucho
# Processing element: tiempo
# Processing element: que
# Processing element: vivía
# Processing element: un
# Processing element: hidalgo
# Processing element: de
# Processing element: los
# Processing element: de
# Processing element: lanza
# Processing element: en
# Processing element: astillero,
# Processing element: adarga
# Processing element: antigua,
# Processing element: rocín
# Processing element: flaco
# Processing element: y
# Processing element: galgo
# Processing element: corredor.
# Processing element: Una
# Processing element: olla
# Processing element: de
# Processing element: algo
# Processing element: más
# Processing element: vaca
# Processing element: que
# Processing element: carnero,
# Processing element: salpicón
# Processing element: las
# Processing element: más
# Processing element: noches,
# Processing element: duelos
# Processing element: y
# Processing element: quebrantos
# Processing element: los
# Processing element: sábados,
# Processing element: lantejas
# Processing element: los
# Processing element: viernes,
# Processing element: algún
# Processing element: palomino
# Processing element: de
# Processing element: añadidura
# Processing element: los
# Processing element: domingos,
# Processing element: consumían
# Processing element: las
# Processing element: tres
# Processing element: partes
# Processing element: de
# Processing element: su
# Processing element: hacienda.
# Processing element: El
# Processing element: resto
# Processing element: della
# Processing element: concluían
# Processing element: sayo
# Processing element: de
# Processing element: velarte,
# Processing element: calzas
# Processing element: de
# Processing element: velludo
# Processing element: para
# Processing element: las
# Processing element: fiestas
# Processing element: con
# Processing element: sus
# Processing element: pantuflos
# Processing element: de
# Processing element: lo
# Processing element: mismo,
# Processing element: los
# Processing element: días
# Processing element: de
# Processing element: entre
# Processing element: semana
# Processing element: se
# Processing element: honraba
# Processing element: con
# Processing element: su
# Processing element: vellorí
# Processing element: de
# Processing element: lo
# Processing element: más
# Processing element: fino.
# bundle finished at: 2024-01-19 20:21:12.619287
# worker finished at: 2024-01-19 20:21:12.700250

# %% [markdown]
# ##### 04 Transformations

# %%
# GroupByKey
with beam.Pipeline(InteractiveRunner()) as p:

    data = (p | "PCollection" >> beam.Create([('Spain', 'Valencia'), ('Spain','Barcelona'), ('France', 'Paris')]))

    (data 
        | "Combined" >> beam.GroupByKey()
        | "Print" >> beam.Map(print))

# %%
# CoGroupByKey
with beam.Pipeline(InteractiveRunner()) as p:

    p1 = p | "PCollection 01" >> beam.Create([('Spain', 'Valencia'), ('Spain','Barcelona'), ('France', 'Paris')])
    p2 = p | "PCollection 02" >> beam.Create([('Spain', 'Madrid'), ('Spain','Alicante'), ('France', 'Lyon')])

    data = ((p1,p2) | beam.CoGroupByKey())

    data | "Print" >> beam.Map(print)

# %%
# Combine
with beam.Pipeline(InteractiveRunner()) as p:

    data = (p | "PCollection" >> beam.Create([('User1', 1), ('User2', 5), ('User1', 7)]))

    (data 
        | "Combined" >> beam.CombinePerKey(sum)
        | "Print" >> beam.Map(print))

# %%
# Flatten
with beam.Pipeline(InteractiveRunner()) as p:

    p1 = p | "PCollection 01" >> beam.Create(['New York', 'Los Angeles', 'Miami', 'Chicago'])
    p2 = p | "Pcollection 02" >> beam.Create(['Madrid', 'Barcelona', 'Valencia', 'Malaga'])
    p3 = p | "Pcollection 03" >> beam.Create(['London','Manchester', 'Liverpool'])

    merged = ((p1,p2,p3)| beam.Flatten())

    merged | beam.Map(print)

# %%
# Partition
countries = ['Spain', 'USA', 'Switzerland']

def partition_fn(country,num_countries):
    return countries.index(country['country'])

with beam.Pipeline(InteractiveRunner()) as p:

        p1,p2,p3 = (
                p 
                | "PCollection" >> beam.Create([
                        {'country': 'Spain', 'city': 'Valencia'},
                        {'country': 'Spain', 'city': 'Barcelona'},
                        {'country': 'USA', 'city': 'New York'},
                        {'country': 'Switzerland', 'city': 'Zurich'},
                        {'country': 'Switzerland', 'city': 'Geneva'}  
                ])
                | "partition" >> beam.Partition(partition_fn, len(countries))
        )

        p3 | "PCollection for Spain" >> beam.Map(print)

# %% [markdown]
# ##### 05 Streaming

# %%
# !pip install "apache_beam[gcp]"
# Out:
# Requirement already satisfied: apache_beam[gcp] in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.53.0)
# Requirement already satisfied: crcmod<2.0,>=1.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (1.7)
# Requirement already satisfied: orjson<4,>=3.9.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (3.9.12)
# Requirement already satisfied: dill<0.3.2,>=0.3.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (0.3.1.1)
# Requirement already satisfied: cloudpickle~=2.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (2.2.1)
# Requirement already satisfied: fastavro<2,>=0.23.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (1.9.3)
# Requirement already satisfied: fasteners<1.0,>=0.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (0.19)
# Requirement already satisfied: grpcio!=1.48.0,<2,>=1.33.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (1.60.0)
# Requirement already satisfied: hdfs<3.0.0,>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (2.7.3)
# Requirement already satisfied: httplib2<0.23.0,>=0.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (0.22.0)
# Requirement already satisfied: js2py<1,>=0.74 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (0.74)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (4.21.0)
# Requirement already satisfied: jsonpickle<4.0.0,>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (3.0.2)
# Requirement already satisfied: numpy<1.25.0,>=1.14.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (1.24.4)
# Requirement already satisfied: objsize<0.7.0,>=0.6.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (0.6.1)
# Requirement already satisfied: packaging>=22.0 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from apache_beam[gcp]) (23.1)
# Requirement already satisfied: pymongo<5.0.0,>=3.8.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (4.6.1)
# Requirement already satisfied: proto-plus<2,>=1.7.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (1.23.0)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.*,!=4.22.0,!=4.23.*,!=4.24.*,<4.26.0,>=3.20.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (4.25.2)
# Requirement already satisfied: pydot<2,>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (1.4.2)
# Requirement already satisfied: python-dateutil<3,>=2.8.0 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from apache_beam[gcp]) (2.8.2)
# Requirement already satisfied: pytz>=2018.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (2023.3.post1)
# Requirement already satisfied: regex>=2020.6.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (2023.12.25)
# Requirement already satisfied: requests<3.0.0,>=2.24.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (4.9.0)
# Requirement already satisfied: zstandard<1,>=0.18.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (0.22.0)
# Requirement already satisfied: pyarrow<15.0.0,>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix<1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (0.6)
# Requirement already satisfied: cachetools<6,>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (5.3.2)
# Requirement already satisfied: google-api-core<3,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (2.15.0)
# Collecting google-apitools<0.5.32,>=0.5.31 (from apache_beam[gcp])
#   Downloading google-apitools-0.5.31.tar.gz (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.5/173.5 kB 2.7 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: google-auth<3,>=1.18.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from apache_beam[gcp]) (2.26.2)
# Collecting google-auth-httplib2<0.2.0,>=0.1.0 (from apache_beam[gcp])
#   Downloading google_auth_httplib2-0.1.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting google-cloud-datastore<3,>=2.0.0 (from apache_beam[gcp])
#   Downloading google_cloud_datastore-2.19.0-py2.py3-none-any.whl.metadata (5.6 kB)
# Collecting google-cloud-pubsub<3,>=2.1.0 (from apache_beam[gcp])
#   Downloading google_cloud_pubsub-2.19.0-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting google-cloud-pubsublite<2,>=1.2.0 (from apache_beam[gcp])
#   Downloading google_cloud_pubsublite-1.9.0-py2.py3-none-any.whl.metadata (5.6 kB)
# Collecting google-cloud-storage<3,>=2.10.0 (from apache_beam[gcp])
#   Downloading google_cloud_storage-2.14.0-py2.py3-none-any.whl.metadata (6.1 kB)
# Collecting google-cloud-bigquery<4,>=2.0.0 (from apache_beam[gcp])
#   Downloading google_cloud_bigquery-3.16.0-py2.py3-none-any.whl.metadata (8.8 kB)
# Collecting google-cloud-bigquery-storage<3,>=2.6.3 (from apache_beam[gcp])
#   Downloading google_cloud_bigquery_storage-2.24.0-py2.py3-none-any.whl.metadata (5.6 kB)
# Collecting google-cloud-core<3,>=2.0.0 (from apache_beam[gcp])
#   Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting google-cloud-bigtable<3,>=2.19.0 (from apache_beam[gcp])
#   Downloading google_cloud_bigtable-2.22.0-py2.py3-none-any.whl.metadata (5.1 kB)
# Collecting google-cloud-spanner<4,>=3.0.0 (from apache_beam[gcp])
#   Downloading google_cloud_spanner-3.41.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting google-cloud-dlp<4,>=3.0.0 (from apache_beam[gcp])
#   Downloading google_cloud_dlp-3.14.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting google-cloud-language<3,>=2.0 (from apache_beam[gcp])
#   Downloading google_cloud_language-2.12.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting google-cloud-videointelligence<3,>=2.0 (from apache_beam[gcp])
#   Downloading google_cloud_videointelligence-2.12.0-py2.py3-none-any.whl.metadata (5.6 kB)
# Collecting google-cloud-vision<4,>=2 (from apache_beam[gcp])
#   Downloading google_cloud_vision-3.5.0-py2.py3-none-any.whl.metadata (5.1 kB)
# Collecting google-cloud-recommendations-ai<0.11.0,>=0.1.0 (from apache_beam[gcp])
#   Downloading google_cloud_recommendations_ai-0.10.6-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting google-cloud-aiplatform<2.0,>=1.26.0 (from apache_beam[gcp])
#   Downloading google_cloud_aiplatform-1.39.0-py2.py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-api-core<3,>=2.0.0->apache_beam[gcp]) (1.62.0)
# Collecting oauth2client>=1.4.12 (from google-apitools<0.5.32,>=0.5.31->apache_beam[gcp])
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 8.7 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.12.0 in /Users/korotchenkostanislav/Library/Python/3.11/lib/python/site-packages (from google-apitools<0.5.32,>=0.5.31->apache_beam[gcp]) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth<3,>=1.18.0->apache_beam[gcp]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-auth<3,>=1.18.0->apache_beam[gcp]) (4.9)
# Collecting google-cloud-resource-manager<3.0.0dev,>=1.3.3 (from google-cloud-aiplatform<2.0,>=1.26.0->apache_beam[gcp])
#   Downloading google_cloud_resource_manager-1.11.0-py2.py3-none-any.whl.metadata (5.2 kB)
# Collecting shapely<3.0.0dev (from google-cloud-aiplatform<2.0,>=1.26.0->apache_beam[gcp])
#   Downloading shapely-2.0.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (7.0 kB)
# Collecting google-resumable-media<3.0dev,>=0.6.0 (from google-cloud-bigquery<4,>=2.0.0->apache_beam[gcp])
#   Downloading google_resumable_media-2.7.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-cloud-bigtable<3,>=2.19.0->apache_beam[gcp]) (0.13.0)
# Requirement already satisfied: grpcio-status>=1.33.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from google-cloud-pubsub<3,>=2.1.0->apache_beam[gcp]) (1.60.0)
# Collecting overrides<8.0.0,>=6.0.1 (from google-cloud-pubsublite<2,>=1.2.0->apache_beam[gcp])
#   Downloading overrides-7.4.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting sqlparse>=0.4.4 (from google-cloud-spanner<4,>=3.0.0->apache_beam[gcp])
#   Downloading sqlparse-0.4.4-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 6.4 MB/s eta 0:00:00
# Collecting deprecated>=1.2.14 (from google-cloud-spanner<4,>=3.0.0->apache_beam[gcp])
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting google-crc32c<2.0dev,>=1.0 (from google-cloud-storage<3,>=2.10.0->apache_beam[gcp])
#   Downloading google_crc32c-1.5.0-cp311-cp311-macosx_10_9_universal2.whl (32 kB)
# Requirement already satisfied: docopt in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from hdfs<3.0.0,>=2.1.0->apache_beam[gcp]) (0.6.2)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from httplib2<0.23.0,>=0.8->apache_beam[gcp]) (3.1.1)
# Requirement already satisfied: tzlocal>=1.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from js2py<1,>=0.74->apache_beam[gcp]) (5.2)
# Requirement already satisfied: pyjsparser>=2.5.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from js2py<1,>=0.74->apache_beam[gcp]) (2.7.1)
# Requirement already satisfied: attrs>=22.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->apache_beam[gcp]) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->apache_beam[gcp]) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->apache_beam[gcp]) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->apache_beam[gcp]) (0.17.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymongo<5.0.0,>=3.8.0->apache_beam[gcp]) (2.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.24.0->apache_beam[gcp]) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.24.0->apache_beam[gcp]) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.24.0->apache_beam[gcp]) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3.0.0,>=2.24.0->apache_beam[gcp]) (2023.11.17)
# Collecting wrapt<2,>=1.10 (from deprecated>=1.2.14->google-cloud-spanner<4,>=3.0.0->apache_beam[gcp])
#   Downloading wrapt-1.16.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: pyasn1>=0.1.7 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from oauth2client>=1.4.12->google-apitools<0.5.32,>=0.5.31->apache_beam[gcp]) (0.5.1)
# Downloading google_auth_httplib2-0.1.1-py2.py3-none-any.whl (9.3 kB)
# Downloading google_cloud_aiplatform-1.39.0-py2.py3-none-any.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 17.2 MB/s eta 0:00:0000:0100:01
# Downloading google_cloud_bigquery-3.16.0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 13.3 MB/s eta 0:00:00
# Downloading google_cloud_bigquery_storage-2.24.0-py2.py3-none-any.whl (190 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 14.1 MB/s eta 0:00:00
# Downloading google_cloud_bigtable-2.22.0-py2.py3-none-any.whl (295 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.1/295.1 kB 17.2 MB/s eta 0:00:00
# Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Downloading google_cloud_datastore-2.19.0-py2.py3-none-any.whl (176 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.4/176.4 kB 13.0 MB/s eta 0:00:00
# Downloading google_cloud_dlp-3.14.0-py2.py3-none-any.whl (157 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.5/157.5 kB 6.5 MB/s eta 0:00:00
# Downloading google_cloud_language-2.12.0-py2.py3-none-any.whl (137 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.8/137.8 kB 8.8 MB/s eta 0:00:00
# Downloading google_cloud_pubsub-2.19.0-py2.py3-none-any.whl (265 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.3/265.3 kB 12.4 MB/s eta 0:00:00
# Downloading google_cloud_pubsublite-1.9.0-py2.py3-none-any.whl (287 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.3/287.3 kB 14.7 MB/s eta 0:00:00
# Downloading google_cloud_recommendations_ai-0.10.6-py2.py3-none-any.whl (172 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 14.1 MB/s eta 0:00:00
# Downloading google_cloud_spanner-3.41.0-py2.py3-none-any.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.1/347.1 kB 13.0 MB/s eta 0:00:00
# Downloading google_cloud_storage-2.14.0-py2.py3-none-any.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 kB 8.6 MB/s eta 0:00:00
# Downloading google_cloud_videointelligence-2.12.0-py2.py3-none-any.whl (228 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.6/228.6 kB 10.1 MB/s eta 0:00:00
# Downloading google_cloud_vision-3.5.0-py2.py3-none-any.whl (442 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 14.2 MB/s eta 0:00:00
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading google_cloud_resource_manager-1.11.0-py2.py3-none-any.whl (320 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.2/320.2 kB 12.4 MB/s eta 0:00:00
# Downloading google_resumable_media-2.7.0-py2.py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 10.3 MB/s eta 0:00:00
# Downloading overrides-7.4.0-py3-none-any.whl (17 kB)
# Downloading shapely-2.0.2-cp311-cp311-macosx_11_0_arm64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.8 MB/s eta 0:00:00a 0:00:01
# Downloading wrapt-1.16.0-cp311-cp311-macosx_11_0_arm64.whl (38 kB)
# Building wheels for collected packages: google-apitools
#   Building wheel for google-apitools (pyproject.toml) ... done
#   Created wheel for google-apitools: filename=google_apitools-0.5.31-py3-none-any.whl size=131015 sha256=c6b43418747a321af44756679e361678ee2a74d2b98a4d1939b6929f0763f73c
#   Stored in directory: /Users/korotchenkostanislav/Library/Caches/pip/wheels/b4/7b/c5/b3dc55a0d70c63727a2fd1332b3cc14193d6d12219aa1372c4
# Successfully built google-apitools
# Installing collected packages: wrapt, sqlparse, shapely, overrides, google-crc32c, oauth2client, google-resumable-media, deprecated, google-auth-httplib2, google-apitools, google-cloud-core, google-cloud-vision, google-cloud-videointelligence, google-cloud-storage, google-cloud-spanner, google-cloud-resource-manager, google-cloud-recommendations-ai, google-cloud-pubsub, google-cloud-language, google-cloud-dlp, google-cloud-datastore, google-cloud-bigtable, google-cloud-bigquery-storage, google-cloud-bigquery, google-cloud-pubsublite, google-cloud-aiplatform
# Successfully installed deprecated-1.2.14 google-apitools-0.5.31 google-auth-httplib2-0.1.1 google-cloud-aiplatform-1.39.0 google-cloud-bigquery-3.16.0 google-cloud-bigquery-storage-2.24.0 google-cloud-bigtable-2.22.0 google-cloud-core-2.4.1 google-cloud-datastore-2.19.0 google-cloud-dlp-3.14.0 google-cloud-language-2.12.0 google-cloud-pubsub-2.19.0 google-cloud-pubsublite-1.9.0 google-cloud-recommendations-ai-0.10.6 google-cloud-resource-manager-1.11.0 google-cloud-spanner-3.41.0 google-cloud-storage-2.14.0 google-cloud-videointelligence-2.12.0 google-cloud-vision-3.5.0 google-crc32c-1.5.0 google-resumable-media-2.7.0 oauth2client-4.1.3 overrides-7.4.0 shapely-2.0.2 sqlparse-0.4.4 wrapt-1.16.0
#
# [notice] A new release of pip is available: 23.3.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
# PubSub
from apache_beam.options.pipeline_options import PipelineOptions

with beam.Pipeline(options=PipelineOptions(streaming=True)) as p:

    data = (p | "ReadFromPubSub" >> beam.io.ReadFromPubSub(subscription='projects/awesome-ridge-411708/subscriptions/edem-topic-sub'))

    data | beam.Map(print)
# Out:
# usage: ipykernel_launcher.py [-h] [--dataflow_endpoint DATAFLOW_ENDPOINT]
#                              [--project PROJECT] [--job_name JOB_NAME]
#                              [--staging_location STAGING_LOCATION]
#                              [--temp_location TEMP_LOCATION] [--region REGION]
#                              [--service_account_email SERVICE_ACCOUNT_EMAIL]
#                              [--no_auth]
#                              [--template_location TEMPLATE_LOCATION]
#                              [--label LABELS] [--update]
#                              [--transform_name_mapping TRANSFORM_NAME_MAPPING]
#                              [--enable_streaming_engine]
#                              [--dataflow_kms_key DATAFLOW_KMS_KEY]
#                              [--create_from_snapshot CREATE_FROM_SNAPSHOT]
#                              [--flexrs_goal {COST_OPTIMIZED,SPEED_OPTIMIZED}]
#                              [--dataflow_service_option DATAFLOW_SERVICE_OPTIONS]
#                              [--enable_hot_key_logging]
#                              [--enable_artifact_caching]
#                              [--impersonate_service_account IMPERSONATE_SERVICE_ACCOUNT]
#                              [--gcp_oauth_scope GCP_OAUTH_SCOPES]
# ipykernel_launcher.py: error: argument --flexrs_goal: invalid choice: '/Users/korotchenkostanislav/Library/Jupyter/runtime/kernel-v2-185782tOXNeM4DCuX.json' (choose from 'COST_OPTIMIZED', 'SPEED_OPTIMIZED')
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/argparse.py:1902, in ArgumentParser.parse_known_args(self, args, namespace)
#    1901 try:
# -> 1902     namespace, args = self._parse_known_args(args, namespace)
#    1903 except ArgumentError as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/argparse.py:2114, in ArgumentParser._parse_known_args(self, arg_strings, namespace)
#    2113     # consume the next optional and any arguments for it
# -> 2114     start_index = consume_optional(start_index)
#    2116 # consume any positionals following the last Optional
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/argparse.py:2054, in ArgumentParser._parse_known_args.<locals>.consume_optional(start_index)
#    2053 for action, args, option_string in action_tuples:
# -> 2054     take_action(action, args, option_string)
#    2055 return stop
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/argparse.py:1962, in ArgumentParser._parse_known_args.<locals>.take_action(action, argument_strings, option_string)
#    1961 seen_actions.add(action)
# -> 1962 argument_values = self._get_values(action, argument_strings)
#    1964 # error if this argument is not allowed with other previously
#    1965 # seen arguments, assuming that actions that use the default
#    1966 # value don't really count as "present"
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/argparse.py:2497, in ArgumentParser._get_values(self, action, arg_strings)
#    2496     value = self._get_value(action, arg_string)
# -> 2497     self._check_value(action, value)
#    2499 # REMAINDER arguments convert all values, checking none
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/argparse.py:2553, in ArgumentParser._check_value(self, action, value)
#    2552 msg = _('invalid choice: %(value)r (choose from %(choices)s)')
# -> 2553 raise ArgumentError(action, msg % args)
#
# ArgumentError: argument --flexrs_goal: invalid choice: '/Users/korotchenkostanislav/Library/Jupyter/runtime/kernel-v2-185782tOXNeM4DCuX.json' (choose from 'COST_OPTIMIZED', 'SPEED_OPTIMIZED')
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[7], line 4
#       2 from apache_beam.options.pipeline_options import PipelineOptions
# ----> 4 with beam.Pipeline(options=PipelineOptions(streaming=True)) as p:
#       6     data = (p | "ReadFromPubSub" >> beam.io.ReadFromPubSub(subscription='projects/awesome-ridge-411708/subscriptions/edem-topic-sub'))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/apache_beam/pipeline.py:209, in Pipeline.__init__(self, runner, options, argv, display_data)
#     208 # Validate pipeline options
# --> 209 errors = PipelineOptionsValidator(self._options, runner).validate()
#     210 if errors:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/apache_beam/options/pipeline_options_validator.py:149, in PipelineOptionsValidator.validate(self)
#     148   if 'validate' in cls.__dict__ and callable(cls.__dict__['validate']):
# --> 149     errors.extend(self.options.view_as(cls).validate(self))
#     150 return errors
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/apache_beam/options/pipeline_options.py:451, in PipelineOptions.view_as(self, cls)
#     430 """Returns a view of current object as provided PipelineOption subclass.
#     431
#     432 Example Usage::
#    (...)
#     449
#     450 """
# --> 451 view = cls(self._flags)
#     453 for option_name in view._visible_option_list():
#     454   # Initialize values of keys defined by a cls.
#     455   #
#    (...)
#     459   # backed by the same list across multiple views, and that any overrides of
#     460   # pipeline options already stored in _all_options are preserved.
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/apache_beam/options/pipeline_options.py:232, in PipelineOptions.__init__(self, flags, **kwargs)
#     230 # The _visible_options attribute will contain options that were recognized
#     231 # by the parser.
# --> 232 self._visible_options, _ = parser.parse_known_args(flags)
#     234 # self._all_options is initialized with overrides to flag values,
#     235 # provided in kwargs, and will store key-value pairs for options recognized
#     236 # by current PipelineOptions [sub]class and its views that may be created.
#    (...)
#     239 # as each new views are created.
#     240 # Users access this dictionary store via __getattr__ / __setattr__ methods.
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/argparse.py:1904, in ArgumentParser.parse_known_args(self, args, namespace)
#    1903     except ArgumentError as err:
# -> 1904         self.error(str(err))
#    1905 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/apache_beam/options/pipeline_options.py:136, in _BeamArgumentParser.error(self, message)
#     135   return
# --> 136 super().error(message)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/argparse.py:2630, in ArgumentParser.error(self, message)
#    2629 args = {'prog': self.prog, 'message': message}
# -> 2630 self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/argparse.py:2617, in ArgumentParser.exit(self, status, message)
#    2616     self._print_message(message, _sys.stderr)
# -> 2617 _sys.exit(status)
#
# SystemExit: 2
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~/Library/Python/3.11/lib/python/site-packages/IPython/core/interactiveshell.py:2097, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2094 if exception_only:
#    2095     stb = ['An exception has occurred, use %tb to see '
#    2096            'the full traceback.\n']
# -> 2097     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2098                                                      value))
#    2099 else:
#    2101     def contains_exceptiongroup(val):
#
# File ~/Library/Python/3.11/lib/python/site-packages/IPython/core/ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~/Library/Python/3.11/lib/python/site-packages/IPython/core/ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~/Library/Python/3.11/lib/python/site-packages/IPython/core/ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File ~/Library/Python/3.11/lib/python/site-packages/IPython/core/ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File ~/Library/Python/3.11/lib/python/site-packages/IPython/core/ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File ~/Library/Python/3.11/lib/python/site-packages/IPython/core/ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File ~/Library/Python/3.11/lib/python/site-packages/IPython/core/ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'
